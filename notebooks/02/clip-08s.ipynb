# %% [markdown]
# Load Julia packages (libraries) needed

# %%
using StanModels, CmdStan, StanMCMCChain
gr(size=(500,500));

# %% [markdown]
# CmdStan uses a tmp directory to store the output of cmdstan

# %%
ProjDir = rel_path_s("..", "scripts", "02")
cd(ProjDir)

# %% [markdown]
# Define the Stan language model

# %%
binomialstanmodel = "
// Inferring a Rate
data {
  int N;
  int<lower=0> k[N];
  int<lower=1> n[N];
}
parameters {
  real<lower=0,upper=1> theta;
  real<lower=0,upper=1> thetaprior;
}
model {
  // Prior Distribution for Rate Theta
  theta ~ beta(1, 1);
  thetaprior ~ beta(1, 1);

  // Observed Counts
  k ~ binomial(n, theta);
}
";

# %% [markdown]
# Define the Stanmodel and set the output format to :mcmcchain.

# %%
stanmodel = Stanmodel(name="binomial", monitors = ["theta"], model=binomialstanmodel,
  output_format=:mcmcchain);
# Use 16 observations
N2 = 15
d = Binomial(9, 0.66)
n2 = Int.(9 * ones(Int, N2));
# Out:
# File /Users/rob/.julia/dev/StanModels/scripts/02/tmp/binomial.stan will be updated.

# %% [markdown]
# Show first 5 (generated) observations

# %%
k2 = rand(d, N2);
k2[1:min(5, N2)]
# Out:
# 5-element Array{Int64,1}:
#  9
#  5
#  4
#  3
#  5

# %% [markdown]
# Input data for cmdstan

# %%
binomialdata = Dict("N" => length(n2), "n" => n2, "k" => k2);

# %% [markdown]
# Sample using cmdstan

# %%
rc, chn, cnames = stan(stanmodel, binomialdata, ProjDir, diagnostics=false,
  CmdStanDir=CMDSTAN_HOME);
# Describe the draws
describe(chn)
# Out:
# Inference for Stan model: binomial_model
# 4 chains: each with iter=(1000,1000,1000,1000); warmup=(0,0,0,0); thin=(1,1,1,1); 4000 iterations saved.
#
# Warmup took (0.028, 0.026, 0.028, 0.028) seconds, 0.11 seconds total
# Sampling took (0.051, 0.047, 0.042, 0.038) seconds, 0.18 seconds total
#
#                 Mean     MCSE  StdDev     5%   50%   95%    N_Eff  N_Eff/s    R_hat
# lp__             -90  2.6e-02     1.0    -92   -90   -89  1.6e+03  9.2e+03  1.0e+00
# accept_stat__   0.90  4.0e-03    0.13   0.62  0.95   1.0  1.1e+03  5.9e+03  1.0e+00
# stepsize__      0.89  5.8e-02   0.082   0.80  0.87   1.0  2.0e+00  1.1e+01  5.3e+13
# treedepth__      1.9  4.0e-02    0.64    1.0   2.0   3.0  2.5e+02  1.4e+03  1.0e+00
# n_leapfrog__     4.4  5.1e-01     4.8    1.0   3.0    11  9.0e+01  5.0e+02  1.0e+00
# divergent__     0.00      nan    0.00   0.00  0.00  0.00      nan      nan      nan
# energy__          91  3.7e-02     1.4     89    91    94  1.5e+03  8.3e+03  1.0e+00
# theta           0.67  7.1e-04   0.040   0.60  0.67  0.73  3.2e+03  1.8e+04  1.0e+00
# thetaprior      0.50  5.4e-03    0.29  0.049  0.50  0.95  2.8e+03  1.6e+04  1.0e+00
#
# Samples were drawn using hmc with nuts.
# For each parameter, N_Eff is a crude measure of effective sample size,
# and R_hat is the potential scale reduction factor on split chains (at
# convergence, R_hat=1).
#
# Iterations = 1:1000
# Thinning interval = 1
# Chains = 1,2,3,4
# Samples per chain = 1000
#
# Empirical Posterior Estimates:
#          Mean       SD       Naive SE        MCSE      ESS
# theta 0.6650642 0.03988546 0.0006306445 0.00068594128 1000
#
# Quantiles:
#          2.5%      25.0%    50.0%    75.0%     97.5%
# theta 0.58444062 0.638842 0.666203 0.6931475 0.7397223

# %% [markdown]
# Allocate array of Normal fits

# %%
fits = Vector{Normal{Float64}}(undef, 4)
for i in 1:4
  fits[i] = fit_mle(Normal, convert.(Float64, chn.value[:, 1, i]))
  println(fits[i])
end
# Out:
# Normal{Float64}(μ=0.6646830029999992, σ=0.0394449411544876)
# Normal{Float64}(μ=0.6644308459999997, σ=0.03986108880565461)
# Normal{Float64}(μ=0.6664214059999999, σ=0.03925800391251653)
# Normal{Float64}(μ=0.6647216210000001, σ=0.040906025059340094)

# %% [markdown]
# Plot the 4 chains

# %%
mu_avg = sum([fits[i].μ for i in 1:4]) / 4.0;
sigma_avg = sum([fits[i].σ for i in 1:4]) / 4.0;

if rc == 0
  p = Vector{Plots.Plot{Plots.GRBackend}}(undef, 4)
  x = 0:0.001:1
  for i in 1:4
    vals = convert.(Float64, chn.value[:, 1, i])
    μ = round(fits[i].μ, digits=2)
    σ = round(fits[i].σ, digits=2)
    p[i] = density(vals, lab="Chain $i density",
       xlim=(0.45, 1.0), title="$(N2) data points")
    plot!(p[i], x, pdf.(Normal(fits[i].μ, fits[i].σ), x), lab="Fitted Normal($μ, $σ)")
  end
  plot(p..., layout=(4, 1))
end
# Out:
# Plot{Plots.GRBackend() n=8}

# %% [markdown]
# Compute at hpd region

# %%
bnds = MCMCChain.hpd(chn[:, 1, :], alpha=0.055);

# %% [markdown]
# Show hpd region

# %%
println("hpd bounds = $bnds\n")
# Out:
# hpd bounds =       94.5% Lower 94.5% Upper
# theta    0.586283    0.738341

# %% [markdown]
# quadratic approximation

# %% [markdown]
# Compute MAP, compare with CmndStan & MLE

# %%
tmp = convert(Array{Float64,3}, chn.value)
draws = reshape(tmp, (size(tmp, 1)*size(tmp, 3)),)
# Out:
# 4000-element Array{Float64,1}:
#  0.638162
#  0.682542
#  0.650576
#  0.652512
#  0.680051
#  0.669667
#  0.666177
#  0.656205
#  0.662049
#  0.599154
#  ⋮
#  0.650914
#  0.650914
#  0.629945
#  0.643538
#  0.659106
#  0.62705
#  0.672544
#  0.654251
#  0.664504

# %% [markdown]
# Compute MAP

# %%
using Optim

x0 = [0.5]
lower = [0.2]
upper = [1.0]

inner_optimizer = GradientDescent()

function loglik(x)
  ll = 0.0
  ll += log.(pdf.(Beta(1, 1), x[1]))
  ll += sum(log.(pdf.(Binomial(9, x[1]), k2)))
  -ll
end

res = optimize(loglik, lower, upper, x0, Fminbox(inner_optimizer))
# Out:
# Results of Optimization Algorithm
#  * Algorithm: Fminbox with Gradient Descent
#  * Starting Point: [0.5]
#  * Minimizer: [0.6666666666236614]
#  * Minimum: 2.834073e+01
#  * Iterations: 4
#  * Convergence: true
#    * |x - x'| ≤ 0.0e+00: true
#      |x - x'| = 0.00e+00
#    * |f(x) - f(x')| ≤ 0.0e+00 |f(x)|: true
#      |f(x) - f(x')| = 0.00e+00 |f(x)|
#    * |g(x)| ≤ 1.0e-08: true
#      |g(x)| = 8.80e-10
#    * Stopped by an increasing objective: false
#    * Reached Maximum Number of Iterations: false
#  * Objective Calls: 87
#  * Gradient Calls: 87

# %% [markdown]
# Summarize mean and sd estimates

# %% [markdown]
# CmdStan mean and sd:

# %%
[mean(chn.value), std(chn.value)]
# Out:
# 2-element Array{Float64,1}:
#  0.6650642189999998
#  0.039885461661469154

# %% [markdown]
# MAP estimate and associated sd:

# %%
[Optim.minimizer(res)[1], std(draws, mean=mean(chn.value))]
# Out:
# 2-element Array{Float64,1}:
#  0.6666666666236614
#  0.03988546166146916

# %% [markdown]
# MLE of mean and sd:

# %%
[mu_avg, sigma_avg]
# Out:
# 2-element Array{Float64,1}:
#  0.6650642189999997
#  0.03986751473299971

# %% [markdown]
# Turing Chain &  89% hpd region boundaries

# %%
plot( x, pdf.(Normal( mu_avg , sigma_avg  ) , x ),
xlim=(0.0, 1.2), lab="Normal approximation using MLE")
plot!( x, pdf.(Normal( Optim.minimizer(res)[1] , std(draws, mean=mean(chn.value))) , x),
lab="Normal approximation using MAP")
density!(draws, lab="CmdStan chain")
vline!([bnds.value[1]], line=:dash, lab="hpd lower bound")
vline!([bnds.value[2]], line=:dash, lab="hpd upper bound")
# Out:
# Plot{Plots.GRBackend() n=5}

# %% [markdown]
# End of `clip_08s.jl`

# %% [markdown]
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
